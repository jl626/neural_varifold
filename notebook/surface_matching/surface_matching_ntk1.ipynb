# %%
import sys
sys.path.append( '../..' )
import os
import torch
import torch.nn as nn 
import torch.nn.functional as F
from pytorch3d.io import load_obj, save_obj, load_ply
from pytorch3d.structures import Meshes
from pytorch3d.utils import ico_sphere
from pytorch3d.ops import sample_points_from_meshes
from pytorch3d.loss import (
    chamfer_distance, 
    mesh_edge_loss, 
    mesh_laplacian_smoothing, 
    mesh_normal_consistency,
)
import numpy as np
from energy import tangent_kernel

# Set the device
if torch.cuda.is_available():
    device = torch.device("cuda:0")
else:
    device = torch.device("cpu")
    print("WARNING: CPU only, this will be slow!")
import input_output 
from benchmark.evaluation_recon_emd import emdModule

# %%
experiment_name = 'hippo'
#experiment_name = 'cup'
#experiment_name = 'dolphin'

# %%
# We read the target 3D model using load_obj
# case 1.  "Cup"
if experiment_name=='cup':
    # two different Cups 
    [VS,FS,FunS] = input_output.loadData("../../data/matching/cup2.ply")
    [VT,FT,FunT] = input_output.loadData("../../data/matching/cup3_broken.ply")
    source = [VS,FS]
    target= [VT,FT]
    # original size
    print(VS.shape)
    print(VT.shape)
    # Option 1 Sampling
    # Decimate source mesh to compute initialization for the multires algorithm 
    param_decimation = {'factor':13/16,'Vol_preser':1, 'Fun_Error_Metric': 1, 'Fun_weigth':0.00} #decimate by a factor of 16
    [verts1,faces1]= input_output.decimate_mesh(VS,FS,param_decimation)
    print(verts1.shape)
    param_decimation = {'factor':13/16,'Vol_preser':1, 'Fun_Error_Metric': 1, 'Fun_weigth':0.00} #decimate by a factor of 16
    [verts2,faces2]= input_output.decimate_mesh(VT,FT,param_decimation)
    print(verts2.shape)
    verts1 = torch.FloatTensor(verts1)
    verts2 = torch.FloatTensor(verts2)
    faces1 = torch.LongTensor(faces1)
    faces2 = torch.LongTensor(faces2)
# Case 2 Dolphin
elif experiment_name == 'dolphin':
    # sphere to dolphine 
    src_mesh = ico_sphere(4)
    VT, FT, FunS = load_obj("../../data/matching/dolphin.obj")
    VS, FS = src_mesh.verts_packed(), src_mesh.faces_packed()
    verts1, faces1 = VS, FS
    verts2, faces2 = VT, FT.verts_idx
# Case 3 Hippocampus 
elif experiment_name == 'hippo':
    verts1, faces1, verts2, faces2 = torch.load('../../data/matching/hippos_red.pt')

# %%
# verts is a FloatTensor of shape (V, 3) where V is the number of vertices in the mesh
# faces is an object which contains the following LongTensors: verts_idx, normals_idx and textures_idx
# For this tutorial, normals and textures are ignored.
faces_idx1 = faces1.to(device)
faces_idx2 = faces2.to(device)

# Mark: obj files
#faces_idx1 = faces1.to(device)#.verts_idx.to(device)
#faces_idx2 = faces2.verts_idx.to(device)

verts1 = verts1.to(device)
verts2 = verts2.to(device)
# We scale normalize and center the target mesh to fit in a sphere of radius 1 centered at (0,0,0). 
# (scale, center) will be used to bring the predicted mesh to its original center and scale
# Note that normalizing the target mesh, speeds up the optimization but is not necessary!
#'''
center1 = verts1.mean(0)
center2 = verts2.mean(0)
verts1 = verts1 - center1
verts2 = verts2 - center2
scale1 = max(verts1.abs().max(0)[0])
scale2 = max(verts2.abs().max(0)[0])
verts1 = verts1 / scale1
verts2 = verts2 / scale2
#'''
# We construct a Meshes structure for the target mesh
src_mesh = Meshes(verts=[verts1], faces=[faces_idx1])
trg_mesh = Meshes(verts=[verts2], faces=[faces_idx2])
print(verts1.shape)
print(verts2.shape)
# Out:
# torch.Size([1654, 3])
# torch.Size([1654, 3])

# %%
class testnet(nn.Module):
    def __init__(self):
        super(testnet, self).__init__()
        self.net = nn.Sequential(nn.Linear(6,64),nn.ReLU(),nn.Linear(64,128),nn.ReLU(),nn.Linear(128,3))
    def forward(self,x):
        return self.net(x)

# %%
# optimizer setting
#deform_verts = torch.full(src_mesh.verts_packed().shape, 0.0, device=device, requires_grad=True)
#optimizer = torch.optim.SGD([deform_verts], lr=.01, momentum=0.9)
#optimizer = torch.optim.Adam([deform_verts], lr=.01)
models = testnet().cuda()
optimizer = torch.optim.Adam(models.parameters(), lr=.001)
#scheduler = torch.optim.lr_scheduler.MultiStepLR(optimizer, milestones=[501,1001], gamma=0.1)

# Number of optimization steps
Niter = 20001

# loss parameters

# weight for varifold loss
w_varifold = 200.0 
# Weight for the chamfer loss
w_chamfer = 1.0 
# Weight for mesh edge loss
w_edge = 1.0 
# Weight for mesh normal consistency
w_normal = 0.1 
# Weight for mesh laplacian smoothing
w_laplacian = 0.1 
# Plot period for the losses
plot_period = 250


chamfer_losses = []
laplacian_losses = []
edge_losses = []
normal_losses = []

varifold = tangent_kernel(1,1.,0.05,3,mode='NTK1')
def compute_engine(V1,V2,L1,L2,K):
    cst_tmp = []
    n_batch = 10000#4096
    for i in range(len(V1)//n_batch + 1):
        tmp = V1[i*n_batch:(i+1)*n_batch,:]
        l_tmp = L1[i*n_batch:(i+1)*n_batch,:]
        v = torch.matmul(K(tmp,V2)*100000,L2)*l_tmp
        cst_tmp.append(v)
    cst = torch.sum(torch.cat(cst_tmp,0))
    return cst

def CompCLNn(F, V):
    if F.shape[1] == 2:
        V0, V1 = V.index_select(0, F[:, 0]), V.index_select(0, F[:, 1])
        C, N  =  (V0 + V1)/2, V1 - V0
    else:
        V0, V1, V2 = V.index_select(0, F[:, 0]), V.index_select(0, F[:, 1]), V.index_select(0, F[:, 2])
        C, N =  (V0 + V1 + V2)/3, .5 * torch.cross(V1 - V0, V2 - V0)

    L = (N ** 2).sum(dim=1)[:, None].sqrt()
    return C, L, N / L, 1#Fun_F

c,l,n,_ = CompCLNn(faces_idx1,verts1)

# %%
for i in range(Niter):
    # Initialize optimizer
    optimizer.zero_grad()
    sv, sf = src_mesh.get_mesh_verts_faces(0)
    sn = src_mesh.verts_normals_packed()
    inputs = torch.cat([sv.cuda(),sn.cuda()],1)
    deform_verts = models(inputs) 

    # Deform the mesh
    new_src_mesh = src_mesh.offset_verts(deform_verts)
    f1 = new_src_mesh.faces_packed()
    v1 = new_src_mesh.verts_packed()
    c1,l1,n1,_ = CompCLNn(f1,v1)
    c2,l2,n2,_ = CompCLNn(faces_idx2,verts2)

    c1 = torch.cat([c1,n1],1)
    c2 = torch.cat([c2,n2],1)
    
    v11 = compute_engine(c1,c1,l1,l1,varifold)
    v22 = compute_engine(c2,c2,l2,l2,varifold) 
    v12 = compute_engine(c2,c1,l2,l1,varifold)

    loss_varifold = v11 + v22 -2*v12

    loss_chamfer, _ = chamfer_distance(c1.unsqueeze(0), c2.unsqueeze(0))

    # and (b) the edge length of the predicted mesh
    loss_edge = mesh_edge_loss(new_src_mesh)
    
    # mesh normal consistency
    loss_normal = mesh_normal_consistency(new_src_mesh)

    # mesh laplacian smoothing
    loss_laplacian = mesh_laplacian_smoothing(new_src_mesh, method="uniform")

    # Weighted sum of the losses
    # note PointNet-NTK1 param = 200 & learning rate 0.01 PointNet-NTK2 = 10 learning rate 0.01
    loss = w_varifold *loss_varifold #+ loss_normal * w_normal # + loss_edge * w_edge + loss_laplacian * w_laplacian 
    # Print the losses
    if i % plot_period==0:
        print('%d Iter: total_loss %.6f Chamfer_loss %.6f Varifold loss %.8f'% (i,loss,loss_chamfer, loss_varifold))
        
    # Optimization step
    loss.backward()
    optimizer.step()
# Out:
# 0 Iter: total_loss 115282.812500 Chamfer_loss 0.166977 Varifold loss 576.41406250
# 250 Iter: total_loss 876.953125 Chamfer_loss 0.051177 Varifold loss 4.38476562
# 500 Iter: total_loss 547.265625 Chamfer_loss 0.047562 Varifold loss 2.73632812
# 750 Iter: total_loss 406.933594 Chamfer_loss 0.045613 Varifold loss 2.03466797
# 1000 Iter: total_loss 330.664062 Chamfer_loss 0.043641 Varifold loss 1.65332031
# 1250 Iter: total_loss 290.039062 Chamfer_loss 0.043323 Varifold loss 1.45019531
# 1500 Iter: total_loss 267.285156 Chamfer_loss 0.042734 Varifold loss 1.33642578
# 1750 Iter: total_loss 247.753906 Chamfer_loss 0.041979 Varifold loss 1.23876953
# 2000 Iter: total_loss 244.531250 Chamfer_loss 0.041108 Varifold loss 1.22265625
# 2250 Iter: total_loss 232.128906 Chamfer_loss 0.040747 Varifold loss 1.16064453
# 2500 Iter: total_loss 210.058594 Chamfer_loss 0.039895 Varifold loss 1.05029297
# 2750 Iter: total_loss 215.136719 Chamfer_loss 0.039483 Varifold loss 1.07568359
# 3000 Iter: total_loss 215.625000 Chamfer_loss 0.039037 Varifold loss 1.07812500
# 3250 Iter: total_loss 209.667969 Chamfer_loss 0.038798 Varifold loss 1.04833984
# 3500 Iter: total_loss 203.222656 Chamfer_loss 0.038330 Varifold loss 1.01611328
# 3750 Iter: total_loss 183.593750 Chamfer_loss 0.038078 Varifold loss 0.91796875
# 4000 Iter: total_loss 184.472656 Chamfer_loss 0.037864 Varifold loss 0.92236328
# 4250 Iter: total_loss 194.531250 Chamfer_loss 0.037518 Varifold loss 0.97265625
# 4500 Iter: total_loss 177.441406 Chamfer_loss 0.037546 Varifold loss 0.88720703
# 4750 Iter: total_loss 172.656250 Chamfer_loss 0.037375 Varifold loss 0.86328125
# 5000 Iter: total_loss 168.652344 Chamfer_loss 0.037114 Varifold loss 0.84326172
# 5250 Iter: total_loss 186.621094 Chamfer_loss 0.036791 Varifold loss 0.93310547
# 5500 Iter: total_loss 177.148438 Chamfer_loss 0.036651 Varifold loss 0.88574219
# 5750 Iter: total_loss 161.816406 Chamfer_loss 0.036614 Varifold loss 0.80908203
# 6000 Iter: total_loss 194.238281 Chamfer_loss 0.036595 Varifold loss 0.97119141
# 6250 Iter: total_loss 163.769531 Chamfer_loss 0.036630 Varifold loss 0.81884766
# 6500 Iter: total_loss 158.593750 Chamfer_loss 0.036631 Varifold loss 0.79296875
# 6750 Iter: total_loss 165.820312 Chamfer_loss 0.036548 Varifold loss 0.82910156
# 7000 Iter: total_loss 166.015625 Chamfer_loss 0.036424 Varifold loss 0.83007812
# 7250 Iter: total_loss 160.644531 Chamfer_loss 0.036388 Varifold loss 0.80322266
# 7500 Iter: total_loss 153.515625 Chamfer_loss 0.036376 Varifold loss 0.76757812
# 7750 Iter: total_loss 151.953125 Chamfer_loss 0.036218 Varifold loss 0.75976562
# 8000 Iter: total_loss 152.832031 Chamfer_loss 0.036169 Varifold loss 0.76416016
# 8250 Iter: total_loss 223.242188 Chamfer_loss 0.036202 Varifold loss 1.11621094
# 8500 Iter: total_loss 155.273438 Chamfer_loss 0.035952 Varifold loss 0.77636719
# 8750 Iter: total_loss 149.804688 Chamfer_loss 0.036069 Varifold loss 0.74902344
# 9000 Iter: total_loss 167.089844 Chamfer_loss 0.036041 Varifold loss 0.83544922
# 9250 Iter: total_loss 154.980469 Chamfer_loss 0.035907 Varifold loss 0.77490234
# 9500 Iter: total_loss 170.800781 Chamfer_loss 0.035985 Varifold loss 0.85400391
# 9750 Iter: total_loss 145.800781 Chamfer_loss 0.035665 Varifold loss 0.72900391
# 10000 Iter: total_loss 148.730469 Chamfer_loss 0.035602 Varifold loss 0.74365234
# 10250 Iter: total_loss 145.117188 Chamfer_loss 0.035545 Varifold loss 0.72558594
# 10500 Iter: total_loss 162.304688 Chamfer_loss 0.035521 Varifold loss 0.81152344
# 10750 Iter: total_loss 143.164062 Chamfer_loss 0.035276 Varifold loss 0.71582031
# 11000 Iter: total_loss 142.968750 Chamfer_loss 0.035249 Varifold loss 0.71484375
# 11250 Iter: total_loss 142.187500 Chamfer_loss 0.035089 Varifold loss 0.71093750
# 11500 Iter: total_loss 149.804688 Chamfer_loss 0.035077 Varifold loss 0.74902344
# 11750 Iter: total_loss 144.140625 Chamfer_loss 0.034951 Varifold loss 0.72070312
# 12000 Iter: total_loss 141.796875 Chamfer_loss 0.035020 Varifold loss 0.70898438
# 12250 Iter: total_loss 140.625000 Chamfer_loss 0.034869 Varifold loss 0.70312500
# 12500 Iter: total_loss 148.437500 Chamfer_loss 0.034904 Varifold loss 0.74218750
# 12750 Iter: total_loss 149.023438 Chamfer_loss 0.034877 Varifold loss 0.74511719
# 13000 Iter: total_loss 152.148438 Chamfer_loss 0.034803 Varifold loss 0.76074219
# 13250 Iter: total_loss 141.406250 Chamfer_loss 0.034795 Varifold loss 0.70703125
# 13500 Iter: total_loss 148.535156 Chamfer_loss 0.034847 Varifold loss 0.74267578
# 13750 Iter: total_loss 137.500000 Chamfer_loss 0.034817 Varifold loss 0.68750000
# 14000 Iter: total_loss 144.921875 Chamfer_loss 0.034801 Varifold loss 0.72460938
# 14250 Iter: total_loss 138.867188 Chamfer_loss 0.034734 Varifold loss 0.69433594
# 14500 Iter: total_loss 137.890625 Chamfer_loss 0.034819 Varifold loss 0.68945312
# 14750 Iter: total_loss 148.828125 Chamfer_loss 0.034743 Varifold loss 0.74414062
# 15000 Iter: total_loss 136.816406 Chamfer_loss 0.034717 Varifold loss 0.68408203
# 15250 Iter: total_loss 144.531250 Chamfer_loss 0.034757 Varifold loss 0.72265625
# 15500 Iter: total_loss 137.109375 Chamfer_loss 0.034631 Varifold loss 0.68554688
# 15750 Iter: total_loss 157.128906 Chamfer_loss 0.034578 Varifold loss 0.78564453
# 16000 Iter: total_loss 136.914062 Chamfer_loss 0.034737 Varifold loss 0.68457031
# 16250 Iter: total_loss 135.644531 Chamfer_loss 0.034713 Varifold loss 0.67822266
# 16500 Iter: total_loss 135.351562 Chamfer_loss 0.034729 Varifold loss 0.67675781
# 16750 Iter: total_loss 135.351562 Chamfer_loss 0.034824 Varifold loss 0.67675781
# 17000 Iter: total_loss 134.472656 Chamfer_loss 0.034660 Varifold loss 0.67236328
# 17250 Iter: total_loss 137.597656 Chamfer_loss 0.034634 Varifold loss 0.68798828
# 17500 Iter: total_loss 143.847656 Chamfer_loss 0.034684 Varifold loss 0.71923828
# 17750 Iter: total_loss 150.390625 Chamfer_loss 0.034696 Varifold loss 0.75195312
# 18000 Iter: total_loss 133.789062 Chamfer_loss 0.034679 Varifold loss 0.66894531
# 18250 Iter: total_loss 141.992188 Chamfer_loss 0.034750 Varifold loss 0.70996094
# 18500 Iter: total_loss 144.238281 Chamfer_loss 0.034534 Varifold loss 0.72119141
# 18750 Iter: total_loss 132.324219 Chamfer_loss 0.034477 Varifold loss 0.66162109
# 19000 Iter: total_loss 145.117188 Chamfer_loss 0.034492 Varifold loss 0.72558594
# 19250 Iter: total_loss 135.839844 Chamfer_loss 0.034391 Varifold loss 0.67919922
# 19500 Iter: total_loss 141.113281 Chamfer_loss 0.034479 Varifold loss 0.70556641
# 19750 Iter: total_loss 136.914062 Chamfer_loss 0.034416 Varifold loss 0.68457031
# 20000 Iter: total_loss 132.910156 Chamfer_loss 0.034495 Varifold loss 0.66455078

# %%
# Fetch the verts and faces of the final predicted mesh
final_verts, final_faces = new_src_mesh.get_mesh_verts_faces(0)

# Scale normalize back to the original target size
final_verts = (final_verts) * scale2 + center2

# Store the predicted mesh using save_obj
save_obj('../../results/pointnet_ntk1_%s.obj'%(experiment_name), final_verts, final_faces)
print('Done!')
# Out:
# Done!

# %%
final_chamfer,_ = chamfer_distance((final_verts.unsqueeze(0).double() - center2)/scale2, verts2.unsqueeze(0).double())
#emd = emdModule()
#emd_val, _ = emd((final_verts.unsqueeze(0) - center2)/scale2,verts2.unsqueeze(0), 1e-3, 3000)
#loss_emd = emd_val.sum()
print('final Chamfer distance: %.6f'%(final_chamfer.detach().cpu().numpy()))
#print(loss_emd)
# Out:
# final Chamfer distance: 0.001374
