# %%
import sys
sys.path.append( '../..' )
import os
import torch
import torch.nn as nn 
import torch.nn.functional as F
from pytorch3d.io import load_obj, save_obj
from pytorch3d.structures import Meshes
from pytorch3d.utils import ico_sphere
from pytorch3d.ops import sample_points_from_meshes
from pytorch3d.loss import (
    chamfer_distance, 
    mesh_edge_loss, 
    mesh_laplacian_smoothing, 
    mesh_normal_consistency,
)
import numpy as np
from energy import tangent_kernel

# Set the device
if torch.cuda.is_available():
    device = torch.device("cuda:0")
else:
    device = torch.device("cpu")
    print("WARNING: CPU only, this will be slow!")
import input_output 
from benchmark.evaluation_recon_emd import emdModule

torch.manual_seed(0)
torch.use_deterministic_algorithms(True, warn_only=True)

# %%
experiment_name = 'hippo'
#experiment_name = 'cup'
#experiment_name = 'dolphin'
#experiment_name ='bunny'

# %%
# We read the target 3D model using load_obj
# case 1.  "Cup"

low = 31
mid = 26
high = 20
if experiment_name=='cup':
    # two different Cups 
    [VS,FS,FunS] = input_output.loadData("../../data/matching/cup2.ply")
    [VT,FT,FunT] = input_output.loadData("../../data/matching/cup3_broken.ply")
    source = [VS,FS]
    target= [VT,FT]
    # original size
    print(VS.shape)
    print(VT.shape)
    # Option 1 Sampling
    # Decimate source mesh to compute initialization for the multires algorithm 
    param_decimation = {'factor':31/32,'Vol_preser':1, 'Fun_Error_Metric': 1, 'Fun_weigth':0.00} #decimate by a factor of 16
    [verts1,faces1]= input_output.decimate_mesh(VS,FS,param_decimation)
    print(verts1.shape)
    param_decimation = {'factor':31/32,'Vol_preser':1, 'Fun_Error_Metric': 1, 'Fun_weigth':0.00} #decimate by a factor of 16
    [verts2,faces2]= input_output.decimate_mesh(VT,FT,param_decimation)
    print(verts2.shape)
    verts1 = torch.FloatTensor(verts1)
    verts2 = torch.FloatTensor(verts2)
    faces1 = torch.LongTensor(faces1)
    faces2 = torch.LongTensor(faces2)
# Case 2 Dolphin
elif experiment_name == 'dolphin':
    # sphere to dolphine 
    src_mesh = ico_sphere(4)
    VT, FT, FunS = load_obj("../../data/matching/dolphin.obj")
    VS, FS = src_mesh.verts_packed(), src_mesh.faces_packed()
    verts1, faces1 = VS, FS
    verts2, faces2 = VT, FT.verts_idx
# Case 3 Hippocampus 
elif experiment_name == 'hippo':
    verts1, faces1, verts2, faces2 = torch.load('../../data/matching/hippos_red.pt')
    #param_decimation = {'factor':13/16,'Vol_preser':1, 'Fun_Error_Metric': 1, 'Fun_weigth':0.00} #decimate by a factor of 16
    #[verts1,faces1]= input_output.decimate_mesh(verts1.numpy(),faces1.numpy(),param_decimation)
    #print(verts1.shape)
    #param_decimation = {'factor':13/16,'Vol_preser':1, 'Fun_Error_Metric': 1, 'Fun_weigth':0.00} #decimate by a factor of 16
    #[verts2,faces2]= input_output.decimate_mesh(verts2.numpy(),faces2.numpy(),param_decimation)
    #verts1 = torch.FloatTensor(verts1)
    #verts2 = torch.FloatTensor(verts2)
    #faces1 = torch.LongTensor(faces1)
    #faces2 = torch.LongTensor(faces2)
elif experiment_name == 'bunny':
    # sphere to dolphine 
    src_mesh = ico_sphere(4)
    VT, FT, FunS = load_obj("../../data/matching/bunny.obj")
    VS, FS = src_mesh.verts_packed(), src_mesh.faces_packed()
    # Decimate source mesh to compute initialization for the multires algorithm 
    param_decimation = {'factor':17/32,'Vol_preser':1, 'Fun_Error_Metric': 1, 'Fun_weigth':0.00} #decimate by a factor of 16
    [verts1,faces1]= input_output.decimate_mesh(VS.numpy(),FS.numpy(),param_decimation)
    print(verts1.shape)
    param_decimation = {'factor':31/32,'Vol_preser':1, 'Fun_Error_Metric': 1, 'Fun_weigth':0.00} #decimate by a factor of 16
    [verts2,faces2]= input_output.decimate_mesh(VT.numpy(),FT.verts_idx.numpy(),param_decimation)
    print(verts2.shape)
    verts1 = torch.FloatTensor(verts1)
    verts2 = torch.FloatTensor(verts2)
    faces1 = torch.LongTensor(faces1)
    faces2 = torch.LongTensor(faces2)

# %%
# verts is a FloatTensor of shape (V, 3) where V is the number of vertices in the mesh
# faces is an object which contains the following LongTensors: verts_idx, normals_idx and textures_idx
# For this tutorial, normals and textures are ignored.
faces_idx1 = faces1.to(device)
faces_idx2 = faces2.to(device)

# Mark: obj files
#faces_idx1 = faces1.to(device)#.verts_idx.to(device)
#faces_idx2 = faces2.verts_idx.to(device)

verts1 = verts1.to(device)
verts2 = verts2.to(device)
# We scale normalize and center the target mesh to fit in a sphere of radius 1 centered at (0,0,0). 
# (scale, center) will be used to bring the predicted mesh to its original center and scale
# Note that normalizing the target mesh, speeds up the optimization but is not necessary!
#'''
center1 = verts1.mean(0)
center2 = verts2.mean(0)
verts1 = verts1 - center1
verts2 = verts2 - center2
scale1 = max(verts1.abs().max(0)[0])
scale2 = max(verts2.abs().max(0)[0])
verts1 = verts1 / scale1
verts2 = verts2 / scale2
#'''
# We construct a Meshes structure for the target mesh
src_mesh = Meshes(verts=[verts1], faces=[faces_idx1])
trg_mesh = Meshes(verts=[verts2], faces=[faces_idx2])
print(verts1.shape)
print(verts2.shape)
# Out:
# torch.Size([1654, 3])
# torch.Size([1654, 3])

# %%
class testnet(nn.Module):
    def __init__(self):
        super(testnet, self).__init__()
        self.net = nn.Sequential(nn.Linear(6,64),nn.ReLU(),nn.Linear(64,128),nn.ReLU(),nn.Linear(128,3))
    def forward(self,x):
        return self.net(x)

# %%
# optimizer setting
models = testnet().cuda()
optimizer = torch.optim.Adam(models.parameters(), lr=.001)

# Number of optimization steps
Niter = 200001

# loss parameters

# weight for varifold loss
w_varifold = 1000.0 
# Plot period for the losses
plot_period = 1000


chamfer_losses = []
laplacian_losses = []
edge_losses = []
normal_losses = []

varifold = tangent_kernel(5,1.,0.05,3,mode='NTK1')
def compute_engine(V1,V2,L1,L2,K):
    cst_tmp = []
    n_batch = 10000#4096
    for i in range(len(V1)//n_batch + 1):
        tmp = V1[i*n_batch:(i+1)*n_batch,:]
        l_tmp = L1[i*n_batch:(i+1)*n_batch,:]
        v = torch.matmul(K(tmp,V2),L2)*l_tmp
        cst_tmp.append(v)
    cst = torch.sum(torch.cat(cst_tmp,0))
    return cst

def CompCLNn(F, V):
    if F.shape[1] == 2:
        V0, V1 = V.index_select(0, F[:, 0]), V.index_select(0, F[:, 1])
        C, N  =  (V0 + V1)/2, V1 - V0
    else:
        V0, V1, V2 = V.index_select(0, F[:, 0]), V.index_select(0, F[:, 1]), V.index_select(0, F[:, 2])
        C, N =  (V0 + V1 + V2)/3, .5 * torch.cross(V1 - V0, V2 - V0)

    L = (N ** 2).sum(dim=1)[:, None].sqrt()
    return C, L, N / L, 1#Fun_F

c,l,n,_ = CompCLNn(faces_idx1,verts1)

# %%
best = None
best_loss = 0
best_iter = 0

for i in range(Niter):
    # Initialize optimizer
    optimizer.zero_grad()
    sv, sf = src_mesh.get_mesh_verts_faces(0)
    sn = src_mesh.verts_normals_packed()
    inputs = torch.cat([sv.cuda(),sn.cuda()],1)
    deform_verts = models(inputs) 

    # Deform the mesh
    new_src_mesh = src_mesh.offset_verts(deform_verts)
    f1 = new_src_mesh.faces_packed()
    v1 = new_src_mesh.verts_packed()
    c1,l1,n1,_ = CompCLNn(f1,v1)
    c2,l2,n2,_ = CompCLNn(faces_idx2,verts2)

    c1 = torch.cat([c1,n1],1)
    c2 = torch.cat([c2,n2],1)
    
    v11 = compute_engine(c1,c1,l1,l1,varifold)
    v22 = compute_engine(c2,c2,l2,l2,varifold) 
    v12 = compute_engine(c2,c1,l2,l1,varifold)

    loss_varifold = v11 + v22 -2*v12

    loss_chamfer, _ = chamfer_distance(c1.unsqueeze(0), c2.unsqueeze(0))

    # Weighted sum of the losses
    loss = w_varifold *loss_varifold 

    if best_loss == 0:
        best = deform_verts
        best_loss = loss.detach()
        best_iter = 0
    elif best_loss > loss.detach():
        best = deform_verts
        best_loss = loss.detach()
        best_iter = i
        torch.save(models.state_dict(),'../../results/ntk1_%s_n.pth'%experiment_name)

    # Print the losses
    if i % plot_period==0:
        print('%d Iter: total_loss %.6f Chamfer_loss %.6f Varifold loss %.8f'% (i,loss,loss_chamfer, loss_varifold))
        print('current best loss is %d: %.6f'%(best_iter,best_loss))
        
    # Optimization step
    loss.backward()
    optimizer.step()
# Out:
# /home/juheonlee/learning/neural_varifold/notebook/surface_matching/../../energy.py:48: UserWarning: Deterministic behavior was enabled with either `torch.use_deterministic_algorithms(True)` or `at::Context::setDeterministicAlgorithms(true)`, but this operation is not deterministic because it uses CuBLAS and you have CUDA >= 10.2. To enable deterministic behavior in this case, you must set an environment variable before running your PyTorch application: CUBLAS_WORKSPACE_CONFIG=:4096:8 or CUBLAS_WORKSPACE_CONFIG=:16:8. For more information, go to https://docs.nvidia.com/cuda/cublas/index.html#cublasApi_reproducibility (Triggered internally at ../aten/src/ATen/Context.cpp:156.)
#   K = torch.matmul(x1,x2.T)/self.dim_size
# /home/juheonlee/learning/neural_varifold/notebook/surface_matching/../../energy.py:49: UserWarning: Deterministic behavior was enabled with either `torch.use_deterministic_algorithms(True)` or `at::Context::setDeterministicAlgorithms(true)`, but this operation is not deterministic because it uses CuBLAS and you have CUDA >= 10.2. To enable deterministic behavior in this case, you must set an environment variable before running your PyTorch application: CUBLAS_WORKSPACE_CONFIG=:4096:8 or CUBLAS_WORKSPACE_CONFIG=:16:8. For more information, go to https://docs.nvidia.com/cuda/cublas/index.html#cublasApi_reproducibility (Triggered internally at ../aten/src/ATen/Context.cpp:156.)
#   ntk = torch.matmul(x1,x2.T)/self.dim_size
# /tmp/ipykernel_16419/250809613.py:28: UserWarning: Deterministic behavior was enabled with either `torch.use_deterministic_algorithms(True)` or `at::Context::setDeterministicAlgorithms(true)`, but this operation is not deterministic because it uses CuBLAS and you have CUDA >= 10.2. To enable deterministic behavior in this case, you must set an environment variable before running your PyTorch application: CUBLAS_WORKSPACE_CONFIG=:4096:8 or CUBLAS_WORKSPACE_CONFIG=:16:8. For more information, go to https://docs.nvidia.com/cuda/cublas/index.html#cublasApi_reproducibility (Triggered internally at ../aten/src/ATen/Context.cpp:156.)
#   v = torch.matmul(K(tmp,V2),L2)*l_tmp
# /home/juheonlee/anaconda3/envs/jax/lib/python3.8/site-packages/torch/autograd/__init__.py:200: UserWarning: Deterministic behavior was enabled with either `torch.use_deterministic_algorithms(True)` or `at::Context::setDeterministicAlgorithms(true)`, but this operation is not deterministic because it uses CuBLAS and you have CUDA >= 10.2. To enable deterministic behavior in this case, you must set an environment variable before running your PyTorch application: CUBLAS_WORKSPACE_CONFIG=:4096:8 or CUBLAS_WORKSPACE_CONFIG=:16:8. For more information, go to https://docs.nvidia.com/cuda/cublas/index.html#cublasApi_reproducibility (Triggered internally at ../aten/src/ATen/Context.cpp:156.)
#   Variable._execution_engine.run_backward(  # Calls into the C++ engine to run the backward pass
# 0 Iter: total_loss 0.744037 Chamfer_loss 0.129872 Varifold loss 0.00074404
# current best loss is 0: 0.744037
# 1000 Iter: total_loss 0.004273 Chamfer_loss 0.044095 Varifold loss 0.00000427
# current best loss is 999: 0.004269
# 2000 Iter: total_loss 0.003260 Chamfer_loss 0.041013 Varifold loss 0.00000326
# current best loss is 1999: 0.003247
# 3000 Iter: total_loss 0.002937 Chamfer_loss 0.038846 Varifold loss 0.00000294
# current best loss is 2989: 0.002861
# 4000 Iter: total_loss 0.002975 Chamfer_loss 0.037960 Varifold loss 0.00000297
# current best loss is 3970: 0.002651
# 5000 Iter: total_loss 0.002537 Chamfer_loss 0.037297 Varifold loss 0.00000254
# current best loss is 4979: 0.002488
# 6000 Iter: total_loss 0.002393 Chamfer_loss 0.036633 Varifold loss 0.00000239
# current best loss is 5975: 0.002369
# 7000 Iter: total_loss 0.003327 Chamfer_loss 0.036390 Varifold loss 0.00000333
# current best loss is 6980: 0.002284
# 8000 Iter: total_loss 0.002218 Chamfer_loss 0.036284 Varifold loss 0.00000222
# current best loss is 7994: 0.002217
# 9000 Iter: total_loss 0.002217 Chamfer_loss 0.036461 Varifold loss 0.00000222
# current best loss is 8969: 0.002161
# 10000 Iter: total_loss 0.002205 Chamfer_loss 0.036254 Varifold loss 0.00000221
# current best loss is 9993: 0.002116
# 11000 Iter: total_loss 0.002244 Chamfer_loss 0.036022 Varifold loss 0.00000224
# current best loss is 10937: 0.002075
# 12000 Iter: total_loss 0.002140 Chamfer_loss 0.035974 Varifold loss 0.00000214
# current best loss is 11970: 0.002041
# 13000 Iter: total_loss 0.002036 Chamfer_loss 0.035699 Varifold loss 0.00000204
# current best loss is 12964: 0.002012
# 14000 Iter: total_loss 0.002045 Chamfer_loss 0.035644 Varifold loss 0.00000205
# current best loss is 13945: 0.001986
# 15000 Iter: total_loss 0.002213 Chamfer_loss 0.035422 Varifold loss 0.00000221
# current best loss is 14988: 0.001956
# 16000 Iter: total_loss 0.001952 Chamfer_loss 0.035283 Varifold loss 0.00000195
# current best loss is 15928: 0.001941
# 17000 Iter: total_loss 0.002064 Chamfer_loss 0.035103 Varifold loss 0.00000206
# current best loss is 16922: 0.001920
# 18000 Iter: total_loss 0.002051 Chamfer_loss 0.035084 Varifold loss 0.00000205
# current best loss is 17907: 0.001900
# 19000 Iter: total_loss 0.001993 Chamfer_loss 0.035058 Varifold loss 0.00000199
# current best loss is 18889: 0.001887
# 20000 Iter: total_loss 0.001889 Chamfer_loss 0.034949 Varifold loss 0.00000189
# current best loss is 19830: 0.001868
# 21000 Iter: total_loss 0.001924 Chamfer_loss 0.035019 Varifold loss 0.00000192
# current best loss is 20423: 0.001855
# 22000 Iter: total_loss 0.001844 Chamfer_loss 0.034638 Varifold loss 0.00000184
# current best loss is 21732: 0.001837
# 23000 Iter: total_loss 0.001851 Chamfer_loss 0.034552 Varifold loss 0.00000185
# current best loss is 22945: 0.001816
# 24000 Iter: total_loss 0.001844 Chamfer_loss 0.034525 Varifold loss 0.00000184
# current best loss is 23802: 0.001807
# 25000 Iter: total_loss 0.001898 Chamfer_loss 0.034498 Varifold loss 0.00000190
# current best loss is 24856: 0.001790
# 26000 Iter: total_loss 0.001911 Chamfer_loss 0.034210 Varifold loss 0.00000191
# current best loss is 25524: 0.001784
# 27000 Iter: total_loss 0.001824 Chamfer_loss 0.034321 Varifold loss 0.00000182
# current best loss is 26708: 0.001770
# 28000 Iter: total_loss 0.002073 Chamfer_loss 0.034146 Varifold loss 0.00000207
# current best loss is 27873: 0.001758
# 29000 Iter: total_loss 0.001837 Chamfer_loss 0.034164 Varifold loss 0.00000184
# current best loss is 28957: 0.001751
# 30000 Iter: total_loss 0.001824 Chamfer_loss 0.034099 Varifold loss 0.00000182
# current best loss is 29520: 0.001743
# 31000 Iter: total_loss 0.001792 Chamfer_loss 0.033987 Varifold loss 0.00000179
# current best loss is 30619: 0.001736
# 32000 Iter: total_loss 0.001732 Chamfer_loss 0.033962 Varifold loss 0.00000173
# current best loss is 31947: 0.001729
# 33000 Iter: total_loss 0.001740 Chamfer_loss 0.033974 Varifold loss 0.00000174
# current best loss is 32872: 0.001721
# 34000 Iter: total_loss 0.001784 Chamfer_loss 0.033923 Varifold loss 0.00000178
# current best loss is 33905: 0.001710
# 35000 Iter: total_loss 0.001915 Chamfer_loss 0.034107 Varifold loss 0.00000191
# current best loss is 34771: 0.001706
# 36000 Iter: total_loss 0.001937 Chamfer_loss 0.033947 Varifold loss 0.00000194
# current best loss is 35769: 0.001697
# 37000 Iter: total_loss 0.001755 Chamfer_loss 0.033931 Varifold loss 0.00000175
# current best loss is 36676: 0.001691
# 38000 Iter: total_loss 0.002014 Chamfer_loss 0.033943 Varifold loss 0.00000201
# current best loss is 37145: 0.001682
# 39000 Iter: total_loss 0.001829 Chamfer_loss 0.033956 Varifold loss 0.00000183
# current best loss is 38086: 0.001675
# 40000 Iter: total_loss 0.001935 Chamfer_loss 0.033312 Varifold loss 0.00000194
# current best loss is 39681: 0.001671
# 41000 Iter: total_loss 0.001770 Chamfer_loss 0.033594 Varifold loss 0.00000177
# current best loss is 40529: 0.001663
# 42000 Iter: total_loss 0.001673 Chamfer_loss 0.033442 Varifold loss 0.00000167
# current best loss is 41734: 0.001658
# 43000 Iter: total_loss 0.001678 Chamfer_loss 0.033313 Varifold loss 0.00000168
# current best loss is 42284: 0.001654
# 44000 Iter: total_loss 0.002004 Chamfer_loss 0.033118 Varifold loss 0.00000200
# current best loss is 43984: 0.001647
# 45000 Iter: total_loss 0.001675 Chamfer_loss 0.033255 Varifold loss 0.00000167
# current best loss is 44498: 0.001643
# 46000 Iter: total_loss 0.001697 Chamfer_loss 0.033248 Varifold loss 0.00000170
# current best loss is 45530: 0.001639
# 47000 Iter: total_loss 0.001678 Chamfer_loss 0.033254 Varifold loss 0.00000168
# current best loss is 46746: 0.001634
# 48000 Iter: total_loss 0.001885 Chamfer_loss 0.033101 Varifold loss 0.00000188
# current best loss is 47806: 0.001628
# 49000 Iter: total_loss 0.001686 Chamfer_loss 0.033023 Varifold loss 0.00000169
# current best loss is 48943: 0.001626
# 50000 Iter: total_loss 0.001896 Chamfer_loss 0.032767 Varifold loss 0.00000190
# current best loss is 49979: 0.001617
# 51000 Iter: total_loss 0.001621 Chamfer_loss 0.032994 Varifold loss 0.00000162
# current best loss is 49979: 0.001617
# 52000 Iter: total_loss 0.001719 Chamfer_loss 0.032876 Varifold loss 0.00000172
# current best loss is 51772: 0.001611
# 53000 Iter: total_loss 0.001663 Chamfer_loss 0.032862 Varifold loss 0.00000166
# current best loss is 52946: 0.001604
# 54000 Iter: total_loss 0.001736 Chamfer_loss 0.032977 Varifold loss 0.00000174
# current best loss is 53584: 0.001600
# 55000 Iter: total_loss 0.001615 Chamfer_loss 0.032917 Varifold loss 0.00000161
# current best loss is 54062: 0.001598
# 56000 Iter: total_loss 0.001622 Chamfer_loss 0.032741 Varifold loss 0.00000162
# current best loss is 55974: 0.001591
# 57000 Iter: total_loss 0.001747 Chamfer_loss 0.032783 Varifold loss 0.00000175
# current best loss is 56614: 0.001585
# 58000 Iter: total_loss 0.001682 Chamfer_loss 0.032820 Varifold loss 0.00000168
# current best loss is 57778: 0.001581
# 59000 Iter: total_loss 0.001652 Chamfer_loss 0.032832 Varifold loss 0.00000165
# current best loss is 58928: 0.001576
# 60000 Iter: total_loss 0.001624 Chamfer_loss 0.032736 Varifold loss 0.00000162
# current best loss is 59727: 0.001570
# 61000 Iter: total_loss 0.001600 Chamfer_loss 0.032647 Varifold loss 0.00000160
# current best loss is 60584: 0.001568
# 62000 Iter: total_loss 0.001570 Chamfer_loss 0.032548 Varifold loss 0.00000157
# current best loss is 61130: 0.001566
# 63000 Iter: total_loss 0.001578 Chamfer_loss 0.032435 Varifold loss 0.00000158
# current best loss is 62929: 0.001557
# 64000 Iter: total_loss 0.001909 Chamfer_loss 0.032448 Varifold loss 0.00000191
# current best loss is 63738: 0.001553
# 65000 Iter: total_loss 0.001771 Chamfer_loss 0.032104 Varifold loss 0.00000177
# current best loss is 64904: 0.001546
# 66000 Iter: total_loss 0.001557 Chamfer_loss 0.032316 Varifold loss 0.00000156
# current best loss is 65411: 0.001544
# 67000 Iter: total_loss 0.001552 Chamfer_loss 0.032365 Varifold loss 0.00000155
# current best loss is 66782: 0.001539
# 68000 Iter: total_loss 0.001581 Chamfer_loss 0.032320 Varifold loss 0.00000158
# current best loss is 67355: 0.001535
# 69000 Iter: total_loss 0.001617 Chamfer_loss 0.032111 Varifold loss 0.00000162
# current best loss is 68707: 0.001529
# 70000 Iter: total_loss 0.001576 Chamfer_loss 0.032226 Varifold loss 0.00000158
# current best loss is 69825: 0.001524
# 71000 Iter: total_loss 0.001555 Chamfer_loss 0.032223 Varifold loss 0.00000156
# current best loss is 70488: 0.001522
# 72000 Iter: total_loss 0.001565 Chamfer_loss 0.032260 Varifold loss 0.00000156
# current best loss is 70488: 0.001522
# 73000 Iter: total_loss 0.001568 Chamfer_loss 0.032200 Varifold loss 0.00000157
# current best loss is 72760: 0.001518
# 74000 Iter: total_loss 0.001606 Chamfer_loss 0.032187 Varifold loss 0.00000161
# current best loss is 73929: 0.001509
# 75000 Iter: total_loss 0.001658 Chamfer_loss 0.031941 Varifold loss 0.00000166
# current best loss is 74645: 0.001507
# 76000 Iter: total_loss 0.001619 Chamfer_loss 0.031847 Varifold loss 0.00000162
# current best loss is 75770: 0.001505
# 77000 Iter: total_loss 0.001526 Chamfer_loss 0.032038 Varifold loss 0.00000153
# current best loss is 76317: 0.001503
# 78000 Iter: total_loss 0.001704 Chamfer_loss 0.032021 Varifold loss 0.00000170
# current best loss is 77555: 0.001498
# 79000 Iter: total_loss 0.001704 Chamfer_loss 0.031952 Varifold loss 0.00000170
# current best loss is 78668: 0.001494
# 80000 Iter: total_loss 0.001505 Chamfer_loss 0.032035 Varifold loss 0.00000151
# current best loss is 79959: 0.001492
# 81000 Iter: total_loss 0.001498 Chamfer_loss 0.031865 Varifold loss 0.00000150
# current best loss is 80035: 0.001490
# 82000 Iter: total_loss 0.001542 Chamfer_loss 0.031901 Varifold loss 0.00000154
# current best loss is 81931: 0.001483
# 83000 Iter: total_loss 0.001496 Chamfer_loss 0.031788 Varifold loss 0.00000150
# current best loss is 82925: 0.001481
# 84000 Iter: total_loss 0.001652 Chamfer_loss 0.031877 Varifold loss 0.00000165
# current best loss is 83825: 0.001477
# 85000 Iter: total_loss 0.001550 Chamfer_loss 0.031750 Varifold loss 0.00000155
# current best loss is 84726: 0.001475
# 86000 Iter: total_loss 0.001971 Chamfer_loss 0.031746 Varifold loss 0.00000197
# current best loss is 85602: 0.001470
# 87000 Iter: total_loss 0.001730 Chamfer_loss 0.031738 Varifold loss 0.00000173
# current best loss is 85602: 0.001470
# 88000 Iter: total_loss 0.001695 Chamfer_loss 0.031767 Varifold loss 0.00000170
# current best loss is 87797: 0.001466
# 89000 Iter: total_loss 0.001475 Chamfer_loss 0.031733 Varifold loss 0.00000148
# current best loss is 87797: 0.001466
# 90000 Iter: total_loss 0.001462 Chamfer_loss 0.031691 Varifold loss 0.00000146
# current best loss is 89372: 0.001460
# 91000 Iter: total_loss 0.001490 Chamfer_loss 0.031661 Varifold loss 0.00000149
# current best loss is 90317: 0.001457
# 92000 Iter: total_loss 0.001483 Chamfer_loss 0.031628 Varifold loss 0.00000148
# current best loss is 91287: 0.001453
# 93000 Iter: total_loss 0.001526 Chamfer_loss 0.031554 Varifold loss 0.00000153
# current best loss is 91287: 0.001453
# 94000 Iter: total_loss 0.001566 Chamfer_loss 0.031610 Varifold loss 0.00000157
# current best loss is 93533: 0.001449
# 95000 Iter: total_loss 0.001483 Chamfer_loss 0.031548 Varifold loss 0.00000148
# current best loss is 94792: 0.001444
# 96000 Iter: total_loss 0.001464 Chamfer_loss 0.031571 Varifold loss 0.00000146
# current best loss is 95985: 0.001440
# 97000 Iter: total_loss 0.001473 Chamfer_loss 0.031522 Varifold loss 0.00000147
# current best loss is 95985: 0.001440
# 98000 Iter: total_loss 0.001542 Chamfer_loss 0.031512 Varifold loss 0.00000154
# current best loss is 97753: 0.001436
# 99000 Iter: total_loss 0.001552 Chamfer_loss 0.031444 Varifold loss 0.00000155
# current best loss is 97753: 0.001436
# 100000 Iter: total_loss 0.001455 Chamfer_loss 0.031281 Varifold loss 0.00000145
# current best loss is 99569: 0.001434
# 101000 Iter: total_loss 0.001585 Chamfer_loss 0.031280 Varifold loss 0.00000159
# current best loss is 100746: 0.001427
# 102000 Iter: total_loss 0.001438 Chamfer_loss 0.031207 Varifold loss 0.00000144
# current best loss is 100746: 0.001427
# 103000 Iter: total_loss 0.001457 Chamfer_loss 0.031233 Varifold loss 0.00000146
# current best loss is 100746: 0.001427
# 104000 Iter: total_loss 0.001460 Chamfer_loss 0.031345 Varifold loss 0.00000146
# current best loss is 103732: 0.001423
# 105000 Iter: total_loss 0.001486 Chamfer_loss 0.031363 Varifold loss 0.00000149
# current best loss is 103732: 0.001423
# 106000 Iter: total_loss 0.001512 Chamfer_loss 0.031205 Varifold loss 0.00000151
# current best loss is 103732: 0.001423
# 107000 Iter: total_loss 0.001451 Chamfer_loss 0.031326 Varifold loss 0.00000145
# current best loss is 106325: 0.001421
# 108000 Iter: total_loss 0.001477 Chamfer_loss 0.031296 Varifold loss 0.00000148
# current best loss is 107536: 0.001417
# 109000 Iter: total_loss 0.001546 Chamfer_loss 0.031187 Varifold loss 0.00000155
# current best loss is 108021: 0.001416
# 110000 Iter: total_loss 0.001518 Chamfer_loss 0.031176 Varifold loss 0.00000152
# current best loss is 108021: 0.001416
# 111000 Iter: total_loss 0.001458 Chamfer_loss 0.031215 Varifold loss 0.00000146
# current best loss is 110654: 0.001412
# 112000 Iter: total_loss 0.001434 Chamfer_loss 0.031139 Varifold loss 0.00000143
# current best loss is 110654: 0.001412
# 113000 Iter: total_loss 0.001449 Chamfer_loss 0.031226 Varifold loss 0.00000145
# current best loss is 110654: 0.001412
# 114000 Iter: total_loss 0.001537 Chamfer_loss 0.031009 Varifold loss 0.00000154
# current best loss is 113154: 0.001410
# 115000 Iter: total_loss 0.001585 Chamfer_loss 0.031257 Varifold loss 0.00000159
# current best loss is 114752: 0.001404
# 116000 Iter: total_loss 0.001449 Chamfer_loss 0.031071 Varifold loss 0.00000145
# current best loss is 114752: 0.001404
# 117000 Iter: total_loss 0.001520 Chamfer_loss 0.031007 Varifold loss 0.00000152
# current best loss is 116691: 0.001403
# 118000 Iter: total_loss 0.001490 Chamfer_loss 0.031037 Varifold loss 0.00000149
# current best loss is 117146: 0.001399
# 119000 Iter: total_loss 0.001442 Chamfer_loss 0.031041 Varifold loss 0.00000144
# current best loss is 117146: 0.001399
# 120000 Iter: total_loss 0.001438 Chamfer_loss 0.031190 Varifold loss 0.00000144
# current best loss is 119617: 0.001395
# 121000 Iter: total_loss 0.001518 Chamfer_loss 0.031055 Varifold loss 0.00000152
# current best loss is 120341: 0.001393
# 122000 Iter: total_loss 0.001481 Chamfer_loss 0.031185 Varifold loss 0.00000148
# current best loss is 121291: 0.001391
# 123000 Iter: total_loss 0.001419 Chamfer_loss 0.030944 Varifold loss 0.00000142
# current best loss is 121291: 0.001391
# 124000 Iter: total_loss 0.001427 Chamfer_loss 0.031046 Varifold loss 0.00000143
# current best loss is 123395: 0.001382
# 125000 Iter: total_loss 0.001509 Chamfer_loss 0.031180 Varifold loss 0.00000151
# current best loss is 123395: 0.001382
# 126000 Iter: total_loss 0.001399 Chamfer_loss 0.031139 Varifold loss 0.00000140
# current best loss is 123395: 0.001382
# 127000 Iter: total_loss 0.001539 Chamfer_loss 0.031230 Varifold loss 0.00000154
# current best loss is 123395: 0.001382
# 128000 Iter: total_loss 0.001643 Chamfer_loss 0.031197 Varifold loss 0.00000164
# current best loss is 123395: 0.001382
# 129000 Iter: total_loss 0.001479 Chamfer_loss 0.031114 Varifold loss 0.00000148
# current best loss is 128320: 0.001376
# 130000 Iter: total_loss 0.001526 Chamfer_loss 0.030847 Varifold loss 0.00000153
# current best loss is 128320: 0.001376
# 131000 Iter: total_loss 0.001421 Chamfer_loss 0.030909 Varifold loss 0.00000142
# current best loss is 128320: 0.001376
# 132000 Iter: total_loss 0.001423 Chamfer_loss 0.030941 Varifold loss 0.00000142
# current best loss is 131839: 0.001371
# 133000 Iter: total_loss 0.001447 Chamfer_loss 0.031127 Varifold loss 0.00000145
# current best loss is 132526: 0.001369
# 134000 Iter: total_loss 0.001412 Chamfer_loss 0.031028 Varifold loss 0.00000141
# current best loss is 132526: 0.001369
# 135000 Iter: total_loss 0.001408 Chamfer_loss 0.030907 Varifold loss 0.00000141
# current best loss is 134741: 0.001365
# 136000 Iter: total_loss 0.001494 Chamfer_loss 0.030949 Varifold loss 0.00000149
# current best loss is 135416: 0.001363
# 137000 Iter: total_loss 0.001710 Chamfer_loss 0.031156 Varifold loss 0.00000171
# current best loss is 136816: 0.001362
# 138000 Iter: total_loss 0.001373 Chamfer_loss 0.030646 Varifold loss 0.00000137
# current best loss is 136816: 0.001362
# 139000 Iter: total_loss 0.001509 Chamfer_loss 0.030890 Varifold loss 0.00000151
# current best loss is 138972: 0.001358
# 140000 Iter: total_loss 0.001378 Chamfer_loss 0.030734 Varifold loss 0.00000138
# current best loss is 138972: 0.001358
# 141000 Iter: total_loss 0.001371 Chamfer_loss 0.030625 Varifold loss 0.00000137
# current best loss is 140337: 0.001354
# 142000 Iter: total_loss 0.001479 Chamfer_loss 0.030644 Varifold loss 0.00000148
# current best loss is 140337: 0.001354
# 143000 Iter: total_loss 0.001393 Chamfer_loss 0.030715 Varifold loss 0.00000139
# current best loss is 140337: 0.001354
# 144000 Iter: total_loss 0.001471 Chamfer_loss 0.030810 Varifold loss 0.00000147
# current best loss is 143835: 0.001349
# 145000 Iter: total_loss 0.001464 Chamfer_loss 0.030763 Varifold loss 0.00000146
# current best loss is 143835: 0.001349
# 146000 Iter: total_loss 0.001390 Chamfer_loss 0.030882 Varifold loss 0.00000139
# current best loss is 145114: 0.001347
# 147000 Iter: total_loss 0.001365 Chamfer_loss 0.030577 Varifold loss 0.00000137
# current best loss is 146718: 0.001345
# 148000 Iter: total_loss 0.001390 Chamfer_loss 0.030731 Varifold loss 0.00000139
# current best loss is 146718: 0.001345
# 149000 Iter: total_loss 0.001501 Chamfer_loss 0.030728 Varifold loss 0.00000150
# current best loss is 148973: 0.001343
# 150000 Iter: total_loss 0.001404 Chamfer_loss 0.030823 Varifold loss 0.00000140
# current best loss is 148973: 0.001343
# 151000 Iter: total_loss 0.001434 Chamfer_loss 0.030824 Varifold loss 0.00000143
# current best loss is 150175: 0.001341
# 152000 Iter: total_loss 0.001350 Chamfer_loss 0.030828 Varifold loss 0.00000135
# current best loss is 151335: 0.001336
# 153000 Iter: total_loss 0.001354 Chamfer_loss 0.030591 Varifold loss 0.00000135
# current best loss is 151335: 0.001336
# 154000 Iter: total_loss 0.001529 Chamfer_loss 0.030669 Varifold loss 0.00000153
# current best loss is 151335: 0.001336
# 155000 Iter: total_loss 0.001395 Chamfer_loss 0.030653 Varifold loss 0.00000140
# current best loss is 154157: 0.001332
# 156000 Iter: total_loss 0.001606 Chamfer_loss 0.030954 Varifold loss 0.00000161
# current best loss is 154157: 0.001332
# 157000 Iter: total_loss 0.001466 Chamfer_loss 0.030727 Varifold loss 0.00000147
# current best loss is 154157: 0.001332
# 158000 Iter: total_loss 0.001347 Chamfer_loss 0.030680 Varifold loss 0.00000135
# current best loss is 154157: 0.001332
# 159000 Iter: total_loss 0.001410 Chamfer_loss 0.030751 Varifold loss 0.00000141
# current best loss is 154157: 0.001332
# 160000 Iter: total_loss 0.001373 Chamfer_loss 0.030586 Varifold loss 0.00000137
# current best loss is 154157: 0.001332
# 161000 Iter: total_loss 0.001337 Chamfer_loss 0.030645 Varifold loss 0.00000134
# current best loss is 160656: 0.001328
# 162000 Iter: total_loss 0.001445 Chamfer_loss 0.030634 Varifold loss 0.00000145
# current best loss is 160656: 0.001328
# 163000 Iter: total_loss 0.001568 Chamfer_loss 0.030660 Varifold loss 0.00000157
# current best loss is 160656: 0.001328
# 164000 Iter: total_loss 0.001444 Chamfer_loss 0.030752 Varifold loss 0.00000144
# current best loss is 160656: 0.001328
# 165000 Iter: total_loss 0.001349 Chamfer_loss 0.030641 Varifold loss 0.00000135
# current best loss is 160656: 0.001328
# 166000 Iter: total_loss 0.001444 Chamfer_loss 0.030517 Varifold loss 0.00000144
# current best loss is 160656: 0.001328
# 167000 Iter: total_loss 0.001425 Chamfer_loss 0.030609 Varifold loss 0.00000142
# current best loss is 166116: 0.001324
# 168000 Iter: total_loss 0.001399 Chamfer_loss 0.030455 Varifold loss 0.00000140
# current best loss is 166116: 0.001324
# 169000 Iter: total_loss 0.001412 Chamfer_loss 0.030506 Varifold loss 0.00000141
# current best loss is 166116: 0.001324
# 170000 Iter: total_loss 0.001475 Chamfer_loss 0.030484 Varifold loss 0.00000148
# current best loss is 166116: 0.001324
# 171000 Iter: total_loss 0.001451 Chamfer_loss 0.030462 Varifold loss 0.00000145
# current best loss is 166116: 0.001324
# 172000 Iter: total_loss 0.001533 Chamfer_loss 0.030653 Varifold loss 0.00000153
# current best loss is 171277: 0.001321
# 173000 Iter: total_loss 0.001336 Chamfer_loss 0.030468 Varifold loss 0.00000134
# current best loss is 171277: 0.001321
# 174000 Iter: total_loss 0.001339 Chamfer_loss 0.030331 Varifold loss 0.00000134
# current best loss is 171277: 0.001321
# 175000 Iter: total_loss 0.001354 Chamfer_loss 0.030316 Varifold loss 0.00000135
# current best loss is 171277: 0.001321
# 176000 Iter: total_loss 0.001507 Chamfer_loss 0.030547 Varifold loss 0.00000151
# current best loss is 175077: 0.001319
# 177000 Iter: total_loss 0.001512 Chamfer_loss 0.030780 Varifold loss 0.00000151
# current best loss is 176907: 0.001317
# 178000 Iter: total_loss 0.001358 Chamfer_loss 0.030419 Varifold loss 0.00000136
# current best loss is 176907: 0.001317
# 179000 Iter: total_loss 0.001403 Chamfer_loss 0.030208 Varifold loss 0.00000140
# current best loss is 176907: 0.001317
# 180000 Iter: total_loss 0.001533 Chamfer_loss 0.030618 Varifold loss 0.00000153
# current best loss is 176907: 0.001317
# 181000 Iter: total_loss 0.001360 Chamfer_loss 0.030485 Varifold loss 0.00000136
# current best loss is 180702: 0.001315
# 182000 Iter: total_loss 0.001403 Chamfer_loss 0.030429 Varifold loss 0.00000140
# current best loss is 180702: 0.001315
# 183000 Iter: total_loss 0.001326 Chamfer_loss 0.030323 Varifold loss 0.00000133
# current best loss is 182935: 0.001313
# 184000 Iter: total_loss 0.001336 Chamfer_loss 0.030608 Varifold loss 0.00000134
# current best loss is 182935: 0.001313
# 185000 Iter: total_loss 0.001403 Chamfer_loss 0.030411 Varifold loss 0.00000140
# current best loss is 182935: 0.001313
# 186000 Iter: total_loss 0.001404 Chamfer_loss 0.030404 Varifold loss 0.00000140
# current best loss is 185860: 0.001311
# 187000 Iter: total_loss 0.001362 Chamfer_loss 0.030589 Varifold loss 0.00000136
# current best loss is 185860: 0.001311
# 188000 Iter: total_loss 0.001321 Chamfer_loss 0.030463 Varifold loss 0.00000132
# current best loss is 187249: 0.001309
# 189000 Iter: total_loss 0.001341 Chamfer_loss 0.030454 Varifold loss 0.00000134
# current best loss is 187249: 0.001309
# 190000 Iter: total_loss 0.001419 Chamfer_loss 0.030590 Varifold loss 0.00000142
# current best loss is 189813: 0.001308
# 191000 Iter: total_loss 0.001565 Chamfer_loss 0.030701 Varifold loss 0.00000156
# current best loss is 189813: 0.001308
# 192000 Iter: total_loss 0.001401 Chamfer_loss 0.030195 Varifold loss 0.00000140
# current best loss is 191388: 0.001306
# 193000 Iter: total_loss 0.001386 Chamfer_loss 0.030619 Varifold loss 0.00000139
# current best loss is 191388: 0.001306
# 194000 Iter: total_loss 0.001390 Chamfer_loss 0.030519 Varifold loss 0.00000139
# current best loss is 191388: 0.001306
# 195000 Iter: total_loss 0.001352 Chamfer_loss 0.030557 Varifold loss 0.00000135
# current best loss is 194059: 0.001304
# 196000 Iter: total_loss 0.001486 Chamfer_loss 0.030428 Varifold loss 0.00000149
# current best loss is 194059: 0.001304
# 197000 Iter: total_loss 0.001330 Chamfer_loss 0.030342 Varifold loss 0.00000133
# current best loss is 196954: 0.001302
# 198000 Iter: total_loss 0.001309 Chamfer_loss 0.030394 Varifold loss 0.00000131
# current best loss is 196954: 0.001302
# 199000 Iter: total_loss 0.001302 Chamfer_loss 0.030403 Varifold loss 0.00000130
# current best loss is 196954: 0.001302
# 200000 Iter: total_loss 0.001317 Chamfer_loss 0.030446 Varifold loss 0.00000132
# current best loss is 196954: 0.001302

# %%
# Fetch the verts and faces of the final predicted mesh
new_src_mesh = src_mesh.offset_verts(best)
final_verts, final_faces = new_src_mesh.get_mesh_verts_faces(0)

# Scale normalize back to the original target size
final_verts = (final_verts) * scale2 + center2

# Store the predicted mesh using save_obj
save_obj('../../results/pointnet_ntk1_%s_low.obj'%(experiment_name), final_verts, final_faces)
print('Done!')
# Out:
# Done!

# %%
final_chamfer,_ = chamfer_distance((final_verts.unsqueeze(0).double() - center2)/scale2, verts2.unsqueeze(0).double())
print('final Chamfer distance: %.6f'%(final_chamfer.detach().cpu().numpy()))
# Out:
# final Chamfer distance: 0.001213
